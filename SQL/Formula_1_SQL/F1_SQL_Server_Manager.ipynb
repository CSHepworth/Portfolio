# %%
import pandas as pd
import pyodbc

# %%
circuits_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/circuits.csv")

constructor_results_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/constructor_results.csv")

constructor_standings_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/constructor_standings.csv")

constructors_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/constructors.csv")

driver_standings_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/driver_standings.csv")

drivers_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/drivers.csv")

lap_times_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/lap_times.csv")

pit_stops_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/pit_stops.csv")

qualifying_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/qualifying.csv")

races_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/races.csv")

results_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/results.csv")

seasons_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/seasons.csv")

sprint_results_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/sprint_results.csv")

status_df = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/status.csv")

# %%
import platform

print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'MySQL ODBC 8.0 ANSI Driver', 'MySQL ODBC 8.0 Unicode Driver', 'SQL Server Native Client RDA 11.0', 'ODBC Driver 18 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'ODBC Driver 17 for SQL Server']

# %%
conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=HK-47\\SQLEXPRESS;"
    "DATABASE=formula1_db;"
    "Trusted_Connection=yes;"
)

cursor = conn.cursor()

# %%
cursor.fast_executemany = True

circuits_df = circuits_df.drop(columns = ["circuitId"])

circuits = list(circuits_df.itertuples(index=False, name=None))

cursor.executemany("""
    INSERT INTO circuits (circuitRef, name, location, country, lat, lng, alt, url)
    VALUES (?, ?, ?, ?, ?, ?, ?, ?)
""", circuits)

conn.commit()

# %%
def load_csv_to_sql_server(cursor, dataframe, ):
    cursor.fast_executemany = True

    dataframe
    pass
