# %%
import pandas as pd
import numpy as np

# %%
circuits = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/circuits.csv")

constructor_results = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/constructor_results.csv")

constructor_standings = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/constructor_standings.csv")

constructors = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/constructors.csv")

driver_standings = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/driver_standings.csv")

drivers = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/drivers.csv")

lap_times = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/lap_times.csv")

pit_stops = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/pit_stops.csv")

qualifying = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/qualifying.csv")

races = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/races.csv")

results = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/results.csv")

seasons = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/seasons.csv")

sprint_results = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/sprint_results.csv")

status = pd.read_csv("../../WGU-Capstone-Project/f1db_csv/status.csv")
