# %% [markdown]
# https://www.kaggle.com/datasets/pralabhpoudel/world-energy-consumption

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_rows", 200)

# %%
WEC_Dataframe = pd.read_csv("World Energy Consumption.csv")

WEC_Dataframe.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
WEC_Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Columns: 129 entries, country to wind_share_energy
# dtypes: float64(126), int64(1), object(2)
# memory usage: 21.7+ MB

# %%
WEC_Dataframe.describe()
# Out:
#                year    population           gdp  biofuel_cons_change_pct  \
# count  22012.000000  1.812300e+04  1.111300e+04              1747.000000
# mean    1974.213247  1.053096e+08  3.585114e+11                46.091694
# std       35.058653  4.640460e+08  2.411179e+12               274.616745
# min     1900.000000  1.833000e+03  1.642060e+08              -100.000000
# 25%     1946.000000  1.712404e+06  1.365898e+10                -0.616500
# 50%     1984.000000  6.991543e+06  4.167411e+10                 8.179000
# 75%     2003.000000  2.557688e+07  1.744295e+11                26.508500
# max     2022.000000  7.975105e+09  1.136302e+14              5659.328000
#
#        biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# count              2687.000000              2302.000000          2767.000000
# mean                  2.719074               133.558459            38.068209
# std                  10.057018               264.707851           111.623148
# ...

# %%
cols = WEC_Dataframe.columns.tolist()

for c in cols:
    print(c)
# Out:
# country
# year
# iso_code
# population
# gdp
# biofuel_cons_change_pct
# biofuel_cons_change_twh
# biofuel_cons_per_capita
# biofuel_consumption
# biofuel_elec_per_capita
# biofuel_electricity
# biofuel_share_elec
# biofuel_share_energy
# carbon_intensity_elec
# coal_cons_change_pct
# coal_cons_change_twh
# coal_cons_per_capita
# coal_consumption
# coal_elec_per_capita
# coal_electricity
# coal_prod_change_pct
# coal_prod_change_twh
# coal_prod_per_capita
# coal_production
# coal_share_elec
# coal_share_energy
# electricity_demand
# electricity_generation
# electricity_share_energy
# energy_cons_change_pct
# energy_cons_change_twh
# energy_per_capita
# energy_per_gdp
# fossil_cons_change_pct
# fossil_cons_change_twh
# fossil_elec_per_capita
# fossil_electricity
# fossil_energy_per_capita
# fossil_fuel_consumption
# fossil_share_elec
# fossil_share_energy
# gas_cons_change_pct
# gas_cons_change_twh
# gas_consumption
# gas_elec_per_capita
# gas_electricity
# gas_energy_per_capita
# ...

# %%
column_code = pd.read_csv("owid-energy-codebook.csv")

# %%
biofuel_data = WEC_Dataframe[[
    "country", 
    "year",
    "iso_code",
    "population", 
    "gdp", 
    "biofuel_cons_change_pct", 
    "biofuel_cons_change_twh", 
    "biofuel_cons_per_capita", 
    "biofuel_consumption", 
    "biofuel_elec_per_capita", 
    "biofuel_electricity", 
    "biofuel_share_elec", 
    "biofuel_share_energy"
]].copy()

biofuel_data.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  biofuel_electricity  biofuel_share_elec  \
# ...

# %%
biofuel_data = biofuel_data.rename(columns = {
    "biofuel_cons_change_pct": "biofuel-cons_change_pct_%", 
    "biofuel_cons_per_capita": "biofuel_cons_per_capita_kWh",
    "biofuel_consumption": "biofuel_consumption_TWh",
    "biofuel_elec_per_capita": "biofuel_elec_per_capita_kWh",
    "biofuel_electricity": "biofuel_electricity_TWh",
    "biofuel_share_elec": "biofuel_share_elec_%",
    "biofuel_share_energy": "biofuel_share_energy_%"
})

biofuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      22012 non-null  object
#  1   year                         22012 non-null  int64
#  2   iso_code                     16512 non-null  object
#  3   population                   18123 non-null  float64
#  4   gdp                          11113 non-null  float64
#  5   biofuel-cons_change_pct_%    1747 non-null   float64
#  6   biofuel_cons_change_twh      2687 non-null   float64
#  7   biofuel_cons_per_capita_kWh  2302 non-null   float64
#  8   biofuel_consumption_TWh      2767 non-null   float64
#  9   biofuel_elec_per_capita_kWh  5275 non-null   float64
#  10  biofuel_electricity_TWh      5527 non-null   float64
#  11  biofuel_share_elec_%         5492 non-null   float64
# ...

# %%
coal_data = WEC_Dataframe[[
    "country", 
    "year",
    "iso_code",
    "population", 
    "gdp", 
    "coal_cons_change_pct", 
    "coal_cons_change_twh", 
    "coal_cons_per_capita", 
    "coal_consumption", 
    "coal_elec_per_capita", 
    "coal_electricity",
    "coal_prod_change_pct",
    "coal_prod_change_twh",
    "coal_prod_per_capita",
    "coal_production",
    "coal_share_elec", 
    "coal_share_energy",
]].copy()

coal_data.head()
# Out:
#          country  year iso_code  population  gdp  coal_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                   NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                   NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                   NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                   NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                   NaN
#
#    coal_cons_change_twh  coal_cons_per_capita  coal_consumption  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
#
#    coal_elec_per_capita  coal_electricity  coal_prod_change_pct  \
# 0                   NaN             71.03                   NaN
# ...

# %%
coal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               22012 non-null  object
#  1   year                  22012 non-null  int64
#  2   iso_code              16512 non-null  object
#  3   population            18123 non-null  float64
#  4   gdp                   11113 non-null  float64
#  5   coal_cons_change_pct  5258 non-null   float64
#  6   coal_cons_change_twh  5315 non-null   float64
#  7   coal_cons_per_capita  4666 non-null   float64
#  8   coal_consumption      5420 non-null   float64
#  9   coal_elec_per_capita  5850 non-null   float64
#  10  coal_electricity      6444 non-null   float64
#  11  coal_prod_change_pct  9657 non-null   float64
#  12  coal_prod_change_twh  16239 non-null  float64
#  13  coal_prod_per_capita  14718 non-null  float64
# ...

# %%
coal_data = coal_data.rename(columns = {
    "coal_cons_change_pct": "coal-cons_change_pct_%", 
    "coal_cons_per_capita": "coal_cons_per_capita_kWh",
    "coal_consumption": "coal_consumption_TWh",
    "coal_elec_per_capita": "coal_elec_per_capita_kWh",
    "coal_electricity": "coal_electricity_TWh",
    "coal_prod_change_pct": "coal_prod_change_pct_%",
    "coal_prod_per_capita": "coal_prod_per_capita_kWh",
    "coal_production": "coal_production_TWh",
    "coal_share_elec": "coal_share_elec_%",
    "coal_share_energy": "coal_share_energy_%"
})

coal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   22012 non-null  object
#  1   year                      22012 non-null  int64
#  2   iso_code                  16512 non-null  object
#  3   population                18123 non-null  float64
#  4   gdp                       11113 non-null  float64
#  5   coal-cons_change_pct_%    5258 non-null   float64
#  6   coal_cons_change_twh      5315 non-null   float64
#  7   coal_cons_per_capita_kWh  4666 non-null   float64
#  8   coal_consumption_TWh      5420 non-null   float64
#  9   coal_elec_per_capita_kWh  5850 non-null   float64
#  10  coal_electricity_TWh      6444 non-null   float64
#  11  coal_prod_change_pct_%    9657 non-null   float64
#  12  coal_prod_change_twh      16239 non-null  float64
# ...
